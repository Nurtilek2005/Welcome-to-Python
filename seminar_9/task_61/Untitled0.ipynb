# %% [markdown]
# >
# - Прочесть с помощью pandas файл california_housing_test.csv, который находится в папке sample_data
# - Посмотреть сколько в нем строк и столбцов
# - Определить какой тип данных имеют столбцы

# %%
import pandas as pd

df = pd.read_csv('./california_housing_test.csv')

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0    -122.05     37.37                27.0       3885.0           661.0  \
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# - Проверить есть ли в файле пустые значения
# - Показать median_house_value где median_income < 2
# - Показать данные в первых 2 столбцах
# - Выбрать данные где housing_median_age < 20 и median_house_value > 70000

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df[df['median_income'] < 2]['median_house_value']
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
df.iloc[:, :2]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.loc[:, :'total_rooms']
# Out:
#       longitude  latitude  housing_median_age  total_rooms
# 0       -122.05     37.37                27.0       3885.0
# 1       -118.30     34.26                43.0       1510.0
# 2       -117.81     33.78                27.0       3589.0
# 3       -118.36     33.82                28.0         67.0
# 4       -119.67     36.33                19.0       1241.0
# ...         ...       ...                 ...          ...
# 2995    -119.86     34.42                23.0       1450.0
# 2996    -118.14     34.06                27.0       5257.0
# 2997    -119.70     36.30                10.0        956.0
# 2998    -117.12     34.10                40.0         96.0
# 2999    -119.63     34.42                42.0       1765.0
#
# [3000 rows x 4 columns]

# %%
df[(df["housing_median_age"] < 20) & (df["median_house_value"] > 70000)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 4       -119.67     36.33                19.0       1241.0           244.0  \
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# 4          850.0       237.0         2.9375             81700.0
# 7         1341.0       441.0         3.2250            166900.0
# 8         1446.0       599.0         3.6696            194400.0
# 13        1935.0       659.0         4.5625            231200.0
# 16         189.0       107.0         1.8750            181300.0
# ...          ...         ...            ...                 ...
# 2978      1128.0       482.0         3.7562            139700.0
# 2981      2307.0       885.0         2.8285            171300.0
# 2984      2751.0       813.0         2.6111            107000.0
# 2985       642.0       303.0         1.8633            109400.0
# 2991       780.0       250.0         7.1997            253800.0
#
# [792 rows x 9 columns]

# %% [markdown]
# - Определить какое максимальное и минимальное значение median_house_value
#
# - Показать максимальное median_house_value, где median_income = 3.1250
#
# - Узнать какая максимальная population в зоне минимального значения median_house_value

# %%
min = df['median_house_value'].min()
max = df['median_house_value'].max()
df[df['median_house_value'] == min]
df[df['median_house_value'] == max]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 42      -118.06     34.15                37.0       1980.0           226.0  \
# 117     -122.07     37.34                30.0       1851.0           238.0
# 118     -117.18     33.02                15.0       3540.0           453.0
# 128     -122.47     37.79                52.0       2844.0           623.0
# 135     -122.34     37.56                39.0       3562.0           391.0
# ...         ...       ...                 ...          ...             ...
# 2960    -117.89     33.60                36.0       1496.0           247.0
# 2968    -119.23     34.17                18.0       6171.0          1490.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 42         697.0       226.0        15.0001            500001.0
# 117        631.0       236.0        10.1007            500001.0
# 118       1364.0       425.0        13.6623            500001.0
# 128       1380.0       596.0         4.7500            500001.0
# 135       1139.0       391.0        12.6417            500001.0
# ...          ...         ...            ...                 ...
# 2960       441.0       203.0         7.8164            500001.0
# 2968      2164.0      1210.0         3.6875            500001.0
# 2992       232.0        92.0         6.2263            500001.0
# 2993       673.0       390.0         5.1048            500001.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [125 rows x 9 columns]

# %%
max = df['median_house_value'].max()
filter = df['median_income'] == 3.1250
filter_1 = df[df['median_house_value'] == max]
df[filter_1['median_income'] == 3.1250]
# Out:
# C:\Users\nurti\AppData\Local\Temp\ipykernel_2984\2226127415.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[filter_1['median_income'] == 3.1250]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[16], line 4
#       2 filter = df['median_income'] == 3.1250
#       3 filter_1 = df[df['median_house_value'] == max]
# ----> 4 df[filter_1['median_income'] == 3.1250]
#
# File c:\Users\nurti\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3751, in DataFrame.__getitem__(self, key)
#    3749 # Do we have a (boolean) 1d indexer?
#    3750 if com.is_bool_indexer(key):
# -> 3751     return self._getitem_bool_array(key)
#    3753 # We are left with two options: a single key, and a collection of keys,
#    3754 # We interpret tuples as collections only for non-MultiIndex
#    3755 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File c:\Users\nurti\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3804, in DataFrame._getitem_bool_array(self, key)
#    3798     raise ValueError(
#    3799         f"Item wrong length {len(key)} instead of {len(self.index)}."
#    3800     )
#    3802 # check_bool_indexer will throw exception if Series key cannot
#    3803 # be reindexed to match DataFrame rows
# -> 3804 key = check_bool_indexer(self.index, key)
#    3806 if key.all():
#    3807     return self.copy(deep=None)
#
# File c:\Users\nurti\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:2499, in check_bool_indexer(index, key)
#    2497 indexer = result.index.get_indexer_for(index)
#    2498 if -1 in indexer:
# -> 2499     raise IndexingError(
#    2500         "Unalignable boolean Series provided as "
#    2501         "indexer (index of the boolean Series and of "
#    2502         "the indexed object do not match)."
#    2503     )
#    2505 result = result.take(indexer)
#    2507 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).
